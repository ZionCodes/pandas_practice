# %%
import pandas as pd
df = pd.read_csv('costofliving.csv')

# %%
df
# Out:
#      Rank                  City  Cost of Living Index  Rent Index  \
# 0     NaN     Hamilton, Bermuda                149.02       96.10
# 1     NaN   Zurich, Switzerland                131.24       69.26
# 2     NaN    Basel, Switzerland                130.93       49.38
# 3     NaN      Zug, Switzerland                128.13       72.12
# 4     NaN   Lugano, Switzerland                123.99       44.99
# ..    ...                   ...                   ...         ...
# 573   NaN         Kanpur, India                 20.79        3.60
# 574   NaN     Karachi, Pakistan                 20.75        4.84
# 575   NaN  Rawalpindi, Pakistan                 20.52        4.78
# 576   NaN      Multan, Pakistan                 18.68        2.94
# 577   NaN    Peshawar, Pakistan                 18.55        2.37
#
#      Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 0                            124.22           157.89                  155.22
# ...

# %%
df.loc[~df['City'].str.contains('Germany')]
# Out:
#      Rank                  City  Cost of Living Index  Rent Index  \
# 0     NaN     Hamilton, Bermuda                149.02       96.10
# 1     NaN   Zurich, Switzerland                131.24       69.26
# 2     NaN    Basel, Switzerland                130.93       49.38
# 3     NaN      Zug, Switzerland                128.13       72.12
# 4     NaN   Lugano, Switzerland                123.99       44.99
# ..    ...                   ...                   ...         ...
# 573   NaN         Kanpur, India                 20.79        3.60
# 574   NaN     Karachi, Pakistan                 20.75        4.84
# 575   NaN  Rawalpindi, Pakistan                 20.52        4.78
# 576   NaN      Multan, Pakistan                 18.68        2.94
# 577   NaN    Peshawar, Pakistan                 18.55        2.37
#
#      Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 0                            124.22           157.89                  155.22
# ...

# %%
df[df['Cost of Living Index'] > 100]
# Out:
#     Rank                         City  Cost of Living Index  Rent Index  \
# 0    NaN            Hamilton, Bermuda                149.02       96.10
# 1    NaN          Zurich, Switzerland                131.24       69.26
# 2    NaN           Basel, Switzerland                130.93       49.38
# 3    NaN             Zug, Switzerland                128.13       72.12
# 4    NaN          Lugano, Switzerland                123.99       44.99
# 5    NaN        Lausanne, Switzerland                122.03       59.55
# 6    NaN              Beirut, Lebanon                120.47       27.76
# 7    NaN            Bern, Switzerland                118.16       46.12
# 8    NaN          Geneva, Switzerland                114.05       75.05
# 9    NaN            Stavanger, Norway                104.61       35.38
# 10   NaN  Honolulu, HI, United States                103.65       65.07
# 11   NaN                 Oslo, Norway                102.33       46.39
# ...

# %%
df[(df['Rent Index'] > 70) & (df['Local Purchasing Power Index'] < 80)]
# Out:
#      Rank                             City  Cost of Living Index  Rent Index  \
# 0     NaN                Hamilton, Bermuda                149.02       96.10
# 49    NaN             Hong Kong, Hong Kong                 80.71       74.57
# 308   NaN  Abu Dhabi, United Arab Emirates                 57.89       91.80
#
#      Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 0                            124.22           157.89                  155.22
# 49                            77.83            84.72                   58.58
# 308                           73.79            49.79                   58.49
#
#      Local Purchasing Power Index
# 0                           79.43
# 49                          65.74
# 308                         75.22

# %%
df.loc[~df['City'].str.contains('India')]
# Out:
#      Rank                  City  Cost of Living Index  Rent Index  \
# 0     NaN     Hamilton, Bermuda                149.02       96.10
# 1     NaN   Zurich, Switzerland                131.24       69.26
# 2     NaN    Basel, Switzerland                130.93       49.38
# 3     NaN      Zug, Switzerland                128.13       72.12
# 4     NaN   Lugano, Switzerland                123.99       44.99
# ..    ...                   ...                   ...         ...
# 571   NaN    Kabul, Afghanistan                 21.35        3.17
# 574   NaN     Karachi, Pakistan                 20.75        4.84
# 575   NaN  Rawalpindi, Pakistan                 20.52        4.78
# 576   NaN      Multan, Pakistan                 18.68        2.94
# 577   NaN    Peshawar, Pakistan                 18.55        2.37
#
#      Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 0                            124.22           157.89                  155.22
# ...

# %%
df.loc[df['City'].str.contains('Germany|France', regex=True)]
# Out:
#      Rank                           City  Cost of Living Index  Rent Index  \
# 36    NaN                   Nice, France                 84.60       36.10
# 37    NaN                  Paris, France                 84.35       48.79
# 71    NaN                Munich, Germany                 77.52       47.34
# 78    NaN                   Lyon, France                 77.21       31.45
# 92    NaN               Toulouse, France                 76.57       24.74
# 149   NaN             Frankfurt, Germany                 72.78       39.15
# 151   NaN               Grenoble, France                 72.67       21.40
# 159   NaN            Heidelberg, Germany                 72.14       32.91
# 161   NaN               Hamburg, Germany                 72.01       36.75
# 174   NaN                  Bonn, Germany                 71.08       30.96
# 175   NaN              Marseille, France                 71.05       23.86
# ...

# %%
df.loc[df['City'].str.contains('Ni[a-z]*', regex=True)]
# Out:
#      Rank                     City  Cost of Living Index  Rent Index  \
# 36    NaN             Nice, France                 84.60       36.10
# 70    NaN    Nijmegen, Netherlands                 77.80       31.30
# 272   NaN          Nicosia, Cyprus                 64.53       19.34
# 443   NaN           Lagos, Nigeria                 37.33       61.89
# 483   NaN  Nizhny Novgorod, Russia                 33.89        9.92
# 486   NaN              Nis, Serbia                 33.40        7.26
#
#      Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 36                            61.87            83.37                   87.59
# 70                            56.00            65.82                   79.62
# 272                           43.35            52.57                   65.96
# 443                           48.84            39.28                   29.59
# 483                           22.65            27.35                   35.03
# ...

# %%
df.loc[df['City'].str.contains('^Ni[a-z]*', regex=True)]
# Out:
#      Rank                     City  Cost of Living Index  Rent Index  \
# 36    NaN             Nice, France                 84.60       36.10
# 70    NaN    Nijmegen, Netherlands                 77.80       31.30
# 272   NaN          Nicosia, Cyprus                 64.53       19.34
# 483   NaN  Nizhny Novgorod, Russia                 33.89        9.92
# 486   NaN              Nis, Serbia                 33.40        7.26
#
#      Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 36                            61.87            83.37                   87.59
# 70                            56.00            65.82                   79.62
# 272                           43.35            52.57                   65.96
# 483                           22.65            27.35                   35.03
# 486                           21.15            26.46                   24.98
#
#      Local Purchasing Power Index
# 36                          64.22
# ...

# %%
df.groupby(['Rent Index']).mean()
# Out:
#             Rank  Cost of Living Index  Cost of Living Plus Rent Index  \
# Rent Index
# 2.37         NaN                 18.55                           10.97
# 2.94         NaN                 20.36                           12.19
# 2.97         NaN                 22.81                           13.51
# 3.17         NaN                 21.35                           12.83
# 3.45         NaN                 23.97                           14.35
# ...          ...                   ...                             ...
# 90.39        NaN                 89.41                           89.87
# 91.80        NaN                 57.89                           73.79
# 96.10        NaN                149.02                          124.22
# 100.00       NaN                100.00                          100.00
# 108.42       NaN                 93.91                          100.72
#
#             Groceries Index  Restaurant Price Index  \
# Rent Index
# ...

# %%
df.groupby(['Rent Index']).mean()
# Out:
#             Rank  Cost of Living Index  Cost of Living Plus Rent Index  \
# Rent Index
# 2.37         NaN                 18.55                           10.97
# 2.94         NaN                 20.36                           12.19
# 2.97         NaN                 22.81                           13.51
# 3.17         NaN                 21.35                           12.83
# 3.45         NaN                 23.97                           14.35
# ...          ...                   ...                             ...
# 90.39        NaN                 89.41                           89.87
# 91.80        NaN                 57.89                           73.79
# 96.10        NaN                149.02                          124.22
# 100.00       NaN                100.00                          100.00
# 108.42       NaN                 93.91                          100.72
#
#             Groceries Index  Restaurant Price Index  \
# Rent Index
# ...
